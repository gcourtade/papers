# %% [markdown]
# # DESCRIPTION
#
# In this notebook we are going to finalize the study of the infulence of the substrates on the GumK closure by using the umbrella sampling strategy. So we are going to follow the same procedure as before e.g. generating the conformations uing SMD and performing the umbrella sampling using the optimized ladder.
#
# So we need to work on three different systems:
#
# - GumK bound to the membrane
# - GumK with the donor partially constrained to the membrane
# - GumK with the acceptor partially constrained.

# %%
root="/mnt/d/PhD"

# %% [markdown]
# ---

# %% [markdown]
# ## Free protein
#
# In this case we are going to generate the conformations by running a SMD on the protein bound to the memebrane. The complex that is used in this case is taken from previus studies.
