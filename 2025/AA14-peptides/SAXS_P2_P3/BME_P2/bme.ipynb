# %% [markdown]
# # Iterative BME
#
#
# When dealing with SAXS data it is possible to fit the weights and the parameters in the linear regression iteratively. This can be done automatically by calling the function ibme().
#
#
# Assume $F^{(0)}_{j,i}$ are $i=1\cdots m$ observables calculated on $j=1\cdots N$ frames. Each frame has an initial weight $w_j^{(0)}$. For each observation, $F_{i}^{\text{EXP}}$ is the corresponding experimental measure.
#
# The iterative BME procedure consists in the following steps:
#
#   1. Calculate ensemble average $\langle F \rangle^{(k)} = \sum_{j}w_j^{(k)} F^{(k)}_{j,i}$
#   2. Perform a linear regression, and determine the optimal parameters $\alpha^{(k)},\beta^{(k)}  = fit(\langle F \rangle ^{(k)},F_j^{\text{CALC}})$
#   3. Transform the dataset $F_{j,i}^{(k+1)} =  \alpha^{(k)} F^{(k)}_{j,i} + \beta^{(k)} $
#   4. Perform a BME fit and calculate the optimal parameters $w^{(k+1)} = BME(F^{(k+1)},w^{(0)}) $
#   5. Iterate over 1-4 until the procedure converges, i.e. the improvement over the optimized $\chi^2$ drops below a tolerance value `ftol`

# %%
import sys,os
import numpy as np
bme_dir = '/home/courtade/BME2/'
sys.path.append(bme_dir)
import BME as BME
import matplotlib.pyplot as plt

# %%
# define input file names
exp_file = "exp_data.dat"
calc_file = "calc_data.dat"
name = "NOCys"
#calc_saxs.txt.zip
# initialize. A name must be specified 
rew = BME.Reweight(name)

# load the experimental and calculated datasets
rew.load(exp_file,calc_file)

# %%
thetas = [0.1, 1, 10, 100, 1000]
do = False

if do:


    fig, ax = plt.subplots(figsize=(20, 10))
    chi2 = []
    phis = []
    for t in thetas:
        print("Running with theta={}".format(t))
        X = rew.ibme(theta=t,iterations=50,ftol=0.02,offset=True)
        chi2_before, chi2_after, phi = X[0], X[1], X[2]
        phis.append(phi)
        chi2.append(chi2_after/chi2_before)
        print("Chi2 before BME %.2f" % chi2_before)
        print("Chi2 after  BME %.2f" % chi2_after)
        print("Fraction of effective frames %.2f" % phi)
        #(t,chi2_after/chi2_before,c="k")
        plt.scatter(t,phi,c="r")
    with open('theta_analysis.csv', 'w') as f:
        f.write("#Theta, Phi, Chi2\n")
        for t, phi, chi in zip(thetas, phis, chi2):
            f.write("{},{},{}\n".format(t, phi, chi))
    plt.plot(thetas,phis,"-o",label="Phi",c="k")
    plt.plot(thetas,chi2,"-o",label="Chi2 reduction",c="r")
    plt.legend()
    plt.xscale('log')
    plt.xlabel("Theta")

# %%
theta=10

# initialize. A name must be specified 
rew = BME.Reweight(name)

# load the experimental and calculated datasets
rew.load(exp_file,calc_file)

# fit the data 
X = rew.ibme(theta=theta,iterations=50,ftol=0.02,offset=True)
chi2_before, chi2_after, phi = X[0], X[1], X[2]

# print statistics
print("Chi2 before BME %.2f" % chi2_before)
print("Chi2 after  BME %.2f" % chi2_after)
print("Fraction of effective frames %.2f" % phi)
# Out:
# Iterative procedure converged below tolerance 9.45e-03 after 4 iterations
# Chi2 before BME 4.16
# Chi2 after  BME 1.58
# Fraction of effective frames 0.41

# %%
w0 = rew.get_w0()
w_new = rew.get_weights()

fig, ax = plt.subplots(figsize=(20, 10))
plt.scatter(range(len(w0)),w_new,label="Optimized weights")
plt.scatter(range(len(w0)),w0,label="Initial weights")
plt.ylim(0,w_new.max()*1.1)
plt.legend()
plt.show()
plt.close()

# %%
sampled_conformations =  w_new.argsort()[::-1][:10]+1
print('Frames with 10 highest weights:', sampled_conformations)
# Out:
# Frames with 10 highest weights: [5999 4309 3206 6160 5991 4013 1698 6036 4308 6038]

# %%
stats = rew.predict(exp_file,calc_file,name)
data = np.loadtxt(name)

x = data[:,0]
avg_exp = data[:,1]
sigma_exp = data[:,2]
avg_calc = X[3].mean(axis=0)
avg_calc_rew = X[4].mean(axis=0)

with open('data.dat', 'w') as f:
    f.write('# label exp_avg exp_sigma calc_avg calc_avg_rew\n')
    for i,j,k,l,m in zip(x,avg_exp,sigma_exp,avg_calc, avg_calc_rew):
        f.write("%.6f\t%.3e\t%.3e\t%.3e\t%.3e\n" % (i,j,k,l,m))


fig, ax = plt.subplots(figsize=(20, 10))
plt.errorbar(x, avg_exp, yerr=sigma_exp, ecolor='black', capsize=0.6, linewidth=0.6, color='black', label='SAXS')
plt.plot(x, avg_calc,linewidth=1, color='blue', label='MD')
plt.plot(x, avg_calc_rew,linewidth=1, color='red', label='Reweighted')

#plt.fill_between(x, avg_exp-sigma_exp, avg_exp+sigma_exp, color='grey')
fs = 20
ax.tick_params(axis='both', which='major', width=1, length=8)
ax.tick_params(axis='both', which='minor', width=1, length=6)
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'q (Å$^{-1}$)', fontsize=fs)
plt.xticks(fontsize=fs)
plt.yticks(fontsize=fs)
plt.ylabel('I(q)', fontsize=fs)
plt.legend(fontsize=fs)
plt.title(r'$\theta$={}'.format(theta), fontsize=fs)
plt.tight_layout()
# plt.savefig('SAXS_fit.png', dpi=300)
plt.show()

# %%
# Create CDF
cdf = np.cumsum(w_new)
conformations = w_new.argsort()

# Random sampling
num_samples = 100
random_numbers = np.random.rand(num_samples)
sampled_conformations = [conformations[np.searchsorted(cdf, rn)] for rn in random_numbers]

# %%
# use pymol to read each of the frames in sampled_conformations and join them into one pdb file
cmd_str = '/home/courtade/pymol/pymol -c -l make_ensemble.pml'
with open('make_ensemble.pml', 'w') as f:
    for i in sampled_conformations:
        f.write(f"load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame{i}.pdb\n")
    f.write('join_states ensemble, frame*\n')
    #f.write('alter ensemble and id 1-415, chain="A"\n')
    #f.write('alter ensemble and id 416-830, chain="B"\n')
    f.write('save /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/ensemble.pdb, ensemble, 0')
os.system(cmd_str)
# Out:
#  PyMOL(TM) 3.1.5.1 - Incentive Product
#  Copyright (C) Schrodinger, LLC
#
#  This Executable Build integrates and extends Open-Source PyMOL.
#  Detected 8 CPU cores.  Enabled multithreaded rendering.
# PyMOL>spawn make_ensemble.pml
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame5816.pdb
# TITLE     Protein in water t= 581600.00000 step= 290800000
# TITLE     Protein in water t= 581600.00000 step= 290800000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame5816".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame1612.pdb
# TITLE     Protein in water t= 161200.00000 step= 80600000
# TITLE     Protein in water t= 161200.00000 step= 80600000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame1612".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame6138.pdb
# TITLE     Protein in water t= 613800.00000 step= 306900000
# TITLE     Protein in water t= 613800.00000 step= 306900000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame6138".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame6017.pdb
# TITLE     Protein in water t= 601700.00000 step= 300850000
# TITLE     Protein in water t= 601700.00000 step= 300850000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame6017".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame4541.pdb
# TITLE     Protein in water t= 454100.00000 step= 227050000
# TITLE     Protein in water t= 454100.00000 step= 227050000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "fr

#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame8284".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame6570.pdb
# TITLE     Protein in water t= 657000.00000 step= 328500000
# TITLE     Protein in water t= 657000.00000 step= 328500000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame6570".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame2256.pdb
# TITLE     Protein in water t= 225600.00000 step= 112800000
# TITLE     Protein in water t= 225600.00000 step= 112800000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame2256".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame46.pdb
# TITLE     Protein in water t= 4600.00000 step= 2300000
# TITLE     Protein in water t= 4600.00000 step= 2300000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame46".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame8334.pdb
# TITLE     Protein in water t= 833400.00000 step= 416700000
# TITLE     Protein in water t= 833400.00000 step= 416700000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame8334".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame5130.pdb
# TITLE     Protein in water t= 513000.00000 step= 256500000
# TITLE     Protein in water t= 513000.00000 step= 256500000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame5130".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame4932.pdb
# TITLE     Protein in water t= 493200.00000 step= 246600000
# TITLE     Protein in water t= 493200.00000 step= 246600000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame4932".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame8500.pdb
# TITLE     Protein in water t= 850000.00000 step= 425000000
# TITLE     Protein in water t= 850000.00000 step= 425000000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame8500".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame6374.pdb
# TITLE     Protein in water t= 637400.00000 step= 318700000
# TITLE     Protein in water t= 637400.00000 step= 318700000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame6374".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame841.pdb
# TITLE     Protein in water t= 84100.00000 step= 42050000
# TITLE     Protein in water t= 84100.00000 step= 42050000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame841".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame3569.pdb
# TITLE     Protein in water t= 356900.00000 step= 178450000
# TITLE     Protein in water t= 356900.00000 step= 178450000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" appended into object "frame3569", state 2.
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame1619.pdb
# TITLE     Protein in water t= 161900.00000 step= 80950000
# TITLE     Protein in water t= 161900.00000 step= 80950000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame1619".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame7685.pdb
# TITLE     Protein in water t= 768500.00000 step= 384250000
# TITLE     Protein in water t= 768500.00000 step= 384250000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame7685".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame9229.pdb
# TITLE     Protein in water t= 922900.00000 step= 461450000
# TITLE     Protein in water t= 922900.00000 step= 461450000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame9229".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame3843.pdb
# TITLE     Protein in water t= 384300.00000 step= 192150000
# TITLE     Protein in water t= 384300.00000 step= 192150000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame3843".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame6798.pdb
# TITLE     Protein in water t= 679800.00000 step= 339900000
# TITLE     Protein in water t= 679800.00000 step= 339900000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame6798".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame2459.pdb
# TITLE     Protein in water t= 245900.00000 step= 122950000
# TITLE     Protein in water t= 245900.00000 step= 122950000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame2459".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame7203.pdb
# TITLE     Protein in water t= 720300.00000 step= 360150000
# TITLE     Protein in water t= 720300.00000 step= 360150000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame7203".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame8476.pdb
# TITLE     Protein in water t= 847600.00000 step= 423800000
# TITLE     Protein in water t= 847600.00000 step= 423800000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame8476".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame4521.pdb
# TITLE     Protein in water t= 452100.00000 step= 226050000
# TITLE     Protein in water t= 452100.00000 step= 226050000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame4521".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame7790.pdb
# TITLE     Protein in water t= 779000.00000 step= 389500000
# TITLE     Protein in water t= 779000.00000 step= 389500000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame7790".
# PyMOL>load /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/all_frames/frame4514.pdb
# TITLE     Protein in water t= 451400.00000 step= 225700000
# TITLE     Protein in water t= 451400.00000 step= 225700000
#  ObjectMolecule: Read crystal symmetry information.
#  CmdLoad: "" loaded as "frame4514".
# PyMOL>join_states ensemble, frame*
#  Selector: found 405 atoms.
#  Executive: object "ensemble" created.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
#  Selector: found 405 atoms.
# PyMOL>save /home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/ensemble.pdb, ensemble, 0
#  Save: wrote "/home/courtade/Documents/2024_AA14-peptide/simulation/structure/monomer/post_process/ensemble.pdb".
# 0
