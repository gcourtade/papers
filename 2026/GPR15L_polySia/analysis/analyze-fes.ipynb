# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
for i in range(73,93):
    data = np.loadtxt(f'funnel_sia5_core2_GPR15_L_bilayer/fes-rew_{i}.dat')
    plt.plot(data[:,0], data[:,1])
    plt.ylim(0,100)

# %%
x = np.loadtxt('funnel_sia5_core2_GPR15_L_bilayer/x.dat')
y = np.loadtxt('funnel_sia5_core2_GPR15_L_bilayer/y.dat')
plt.plot(x, y)
plt.xlabel('N blocks')
plt.ylabel('Average FES error (kJ/mol)')
# Out:
# Text(0, 0.5, 'Average FES error (kJ/mol)')

# %%
fes = np.loadtxt('funnel_sia5_core2_GPR15_L_bilayer/fes-rew.dat')
plt.errorbar(fes[:,0], fes[:,1], yerr=fes[:,2])
# Out:
# <ErrorbarContainer object of 3 artists>
