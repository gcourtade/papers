# %%
import numpy as np
import pandas as pd
import MDAnalysis as mda
from scipy.stats import gaussian_kde
import matplotlib.pyplot as plt
from tqdm.auto import trange

# %%
def distances_from_multistate_pdb(pdb_file, atomid1=644, atomid2=997):
    u = mda.Universe(pdb_file)
    dists = []

    a1 = u.select_atoms(f"id {atomid1}")
    a2 = u.select_atoms(f"id {atomid2}")
  #  if len(a1) != 1 or len(a2) != 1:
  #      raise ValueError("Expected exactly one atom for each atom id.")
    #print(len(a1.positions))
    #print(a1.positions)
    for i in range(len(a1.positions)):
        d = np.linalg.norm(a1.positions[i] - a2.positions[i])
#        print(d)   
        dists.append(float(d))

    return dists

# %%
def bootstrap_kde(
    dk_replicas: list[list[float]],
    output_csv: str,
    n_bootstrap: int = 4000,
    confidence_level: float = 95,
    x_min: float = 2,
    x_max: float = 12,
    n_points: int = 100,
    bw_scale: float = 0.6
):
    dk_all = [item for sublist in dk_replicas for item in sublist]
    x_grid = np.linspace(x_min, x_max, n_points)

    kde_samples = np.zeros((n_bootstrap, len(x_grid)))
    print("len(dk_replicas):", len(dk_replicas))
    print("len(dk_replicas[0]):", len(dk_replicas[0]))
    print("first few values:", dk_replicas[0][:5])
    for i in trange(n_bootstrap, desc="Bootstrap KDE"):
        sample = np.random.choice(dk_all, size=len(dk_all), replace=True)
        kde = gaussian_kde(sample)
        kde.set_bandwidth(bw_method=kde.factor * bw_scale)
        kde_samples[i, :] = kde(x_grid)

    lower_bound = np.percentile(kde_samples, (100 - confidence_level) / 2, axis=0)
    upper_bound = np.percentile(kde_samples, 100 - (100 - confidence_level) / 2, axis=0)
    kde_mean = np.mean(kde_samples, axis=0)
    kde_std = np.std(kde_samples, axis=0)

    df_out = pd.DataFrame({
        "x": x_grid,
        "kde_mean": kde_mean,
        "kde_std": kde_std,
        "ci_lower": lower_bound,
        "ci_upper": upper_bound
    })
    df_out.to_csv(output_csv, index=False)

    plt.figure(figsize=(8, 5))
    plt.plot(x_grid, kde_mean, label="mean KDE")
    plt.fill_between(
        x_grid,
        lower_bound,
        upper_bound,
        alpha=0.3,
        label=f"CI {confidence_level}%"
    )
    plt.xlabel("distance")
    plt.ylabel("Density")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

    return df_out

# %%
#dkreplicas = [distances_from_multistate_pdb("coordinates/aligned_glca_af3.pdb", 644, 997)]
#dkreplicas = [distances_from_multistate_pdb("coordinates/aligned_glc_af3.pdb", 644, 972)]
#dkreplicas = [distances_from_multistate_pdb("coordinates/aligned_gala_af3.pdb", 644, 972)]
#dkreplicas = [distances_from_multistate_pdb("coordinates/aligned_gal_af3.pdb", 644, 972)]
#dkreplicas = [distances_from_multistate_pdb("coordinates/aligned_glcnac_af3.pdb", 644, 987)]
#dkreplicas = [distances_from_multistate_pdb("coordinates/aligned_galnac_af3.pdb", 644, 987)]
#dkreplicas = [distances_from_multistate_pdb("coordinates/aligned_gal_boltz.pdb", 644, 971)]
#dkreplicas = [distances_from_multistate_pdb("coordinates/aligned_gal_boltz.pdb", 644, 967)]
#dkreplicas = [distances_from_multistate_pdb("coordinates/aligned_galnac_boltz.pdb", 644, 986)]
#dkreplicas = [distances_from_multistate_pdb("coordinates/aligned_glc_boltz.pdb", 644, 971)]
#dkreplicas = [distances_from_multistate_pdb("coordinates/aligned_glca_boltz.pdb", 644, 996)]
dkreplicas = [distances_from_multistate_pdb("coordinates/aligned_glcnac_boltz.pdb", 644, 996)]

df_kde = bootstrap_kde(
    dkreplicas,
    output_csv="output/bootstrap_kde_glcnac_boltz.csv",
    n_bootstrap=4000,
    confidence_level=95,
    x_min=0.0,
    x_max=20.0,
    n_points=200,
    bw_scale=0.6,
)
# Out:
# len(dk_replicas): 1
# len(dk_replicas[0]): 200
# first few values: [4.680820465087891, 4.899626731872559, 4.429839611053467, 5.018469333648682, 4.991652488708496]
# Bootstrap KDE:   0%|          | 0/4000 [00:00<?, ?it/s]

# %%
# !tail -n +1 confidences/boltz/affinity_GumK*
# Out:
# ==> confidences/boltz/affinity_GumK_UDP-GalA.json <==
# {
#     "affinity_pred_value": 1.225355625152588,
#     "affinity_probability_binary": 0.7639608383178711,
#     "affinity_pred_value1": 0.9390809535980225,
#     "affinity_probability_binary1": 0.8325690031051636,
#     "affinity_pred_value2": 1.5116302967071533,
#     "affinity_probability_binary2": 0.6953526139259338
# }
# ==> confidences/boltz/affinity_GumK_UDP-Gal.json <==
# {
#     "affinity_pred_value": -0.2512030005455017,
#     "affinity_probability_binary": 0.8513375520706177,
#     "affinity_pred_value1": 1.7783929109573364,
#     "affinity_probability_binary1": 0.7338086366653442,
#     "affinity_pred_value2": -2.28079891204834,
#     "affinity_probability_binary2": 0.9688665270805359
# }
# ==> confidences/boltz/affinity_GumK_UDP-GalNAc.json <==
# {
#     "affinity_pred_value": -0.17207342386245728,
#     "affinity_probability_binary": 0.6155726313591003,
#     "affinity_pred_value1": 1.1551213264465332,
#     "affinity_probability_binary1": 0.4695875644683838,
#     "affinity_pred_value2": -1.4992681741714478,
#     "affinity_probability_binary2": 0.7615576982498169
# }
# ==> confidences/boltz/affinity_GumK_UDP-GlcA.json <==
# {
#     "affinity_pred_value": -0.6550031304359436,
#     "affinity_probability_binary": 0.8507941961288452,
#     "affinity_pred_value1": 1.0562728643417358,
#     "affinity_probability_binary1": 0.7235854864120483,
#     "affinity_pred_value2": -2.366279125213623,
#     "affinity_probability_binary2": 0.9780028462409973
# }
# ==> confidences/boltz/affinity_GumK_UDP-Glc.json <==
# {
#     "affinity_pred_value": -0.25368553400039673,
#     "affinity_probability_binary": 0.78534334897995,
#     "affinity_pred_value1": 0.9738154411315918,
#     "affinity_probability_binary1": 0.6911435127258301,
#     "affinity_pred_value2": -1.4811865091323853,
#     "affinity_probability_binary2": 0.8795431852340698
# }
# ==> confidences/boltz/affinity_GumK_UDP-GlcNAc.json <==
# {
#     "affinity_pred_value": -0.1348899006843567,
#     "affinity_probability_binary": 0.6099870204925537,
#     "affinity_pred_value1": 1.2407971620559692,
#     "affinity_probability_binary1": 0.45136046409606934,
#     "affinity_pred_value2": -1.5105769634246826,
#     "affinity_probability_binary2": 0.7686135768890381
# }

# %%
10**1.225355625152588
# Out:
# 16.80179281833723

# %%
10**-0.2512030005455017
# Out:
# 0.5607857888857489

# %%
10**-0.17207342386245728
# Out:
# 0.6728628893110224

# %%
10**-0.6550031304359436
# Out:
# 0.2213078757465913

# %%
10**-0.25368553400039673
# Out:
# 0.5575893447217104

# %%
10**-0.1348899006843567
# Out:
# 0.7330103372671377
